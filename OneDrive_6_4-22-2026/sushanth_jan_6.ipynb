# %%
word="HEllo"
print(len(word))
# Out:
# 5

# %%
word="hello"
print(word[::-1])
# Out:
# olleh

# %%
word=str(input(""))
if(word==word[::-1]):
  print("the word is Palindrome")
else:
  print("The word is not Palindrome")
# Out:
# malyalam
# The word is not Palindrome

# %%
word=("h e l l o")
word=word.title()
print(word)
# Out:
# H E L L O

# %%
list1=("mango","apple","orange","banana")
list2=("brinjal","mango","orange","chilli")
for i in list1:
  if i in list2:
    print(i)
# Out:
# mango
# orange

# %%
a=int(input("enter a no "))
if a<=-1:
  print("a=0")
else:
  print(a)
# Out:
# enter a no -6
# a=0

# %%
word="HELLO"
VOWEL="A","E","I","O","U"
for i in word:
  if i in VOWEL:
    print(word.count(i))
# Out:
# 1
# 1
