# %%
N=int(input ("Enter N value"))
print("Soil nitrogen level is",N,"mg/kg")
if N<100:
 print("Recommendation:Apply high level nitrogen \n cost=₹2000/bag \n your soil has no nitrogen ")
elif(100<=N<=250) :
 print("Recommendation:Apply medium level nitrogen \n cost=₹1000/bag \n your soil has little nitrogen")
else:
 print("Recommendation:Apply zero level nitrogen \n cost=₹0/bag \n your soil good  nitrogen")
# Out:
# Enter N value140
# Soil nitrogen level is 140 mg/kg
# Recommendation:Apply medium level nitrogen
#  cost=₹1000/bag
#  your soil has little nitrogen

# %%
crop=input("Enter crop name")
soilmoisture=int(input("Enter the moisture"))
temp=input("Enter the temperature")
print(f"crop:{crop}, soilmoisture:{soilmoisture},temp:{temp}")
if crop == "rice":
    if (soilmoisture < 60) and (temp == "hot"):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is hot \n Estimated water time:50min")
    elif (soilmoisture < 50) and ((temp == "moderate") or (temp == "cool")):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is moderate or cool \n Estimated water time:30min")
    else:
        print("Do not irrigate")
if crop == "wheat":
      if(soilmoisture < 40) and (temp == "hot"):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is hot \n Estimated water time:50min")
      elif(soilmoisture < 30) and ((temp == "moderate") or (temp == "cool")):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is moderate or cool \n Estimated water time:30min")
      else:
        print("Do not irrigate")
if crop == "sugarcane":
      if(soilmoisture < 70) and (temp == "hot"):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is hot \n Estimated water time:50min")
      elif(soilmoisture < 60) and ((temp == "moderate") or (temp == "cool")):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is moderate or cool \n Estimated water time:30min")
      else:
        print("Do not irrigate")
# Out:
# Enter crop namewheat
# Enter the moisture30
# Enter the temperaturehot
# crop:wheat, soilmoisture:30,temp:hot
# Decision:IRRIGATE NOW
#  Reason:soil moisture is low and temperature is hot
#  Estimated water time:50min

# %%
pest=int(input("no. of pest "))
damage=int(input("crop damage percentage:"))
temp=int(input("Enter the temperature"))
humidity=int(input("Enter the humidity"))
print(f"Pests per plant:{pest},Damage:{damage}%,temp:{temp}C,humidity:{humidity}%")
if (pest<5)and (damage<10):
  print("Severity level:Low \n Recommendation: No action required \n cost of intervention=0")
elif (pest<15)and (damage<25):
  print("Severity level:medium \n Recommendation: Monitor daily \n cost of intervention=500/ha")
else:
  print("Severity level:High \n Recommendation: Immediate action required \n cost of intervention=1000/ha")
# Out:
# no. of pest 0
# crop damage percentage:25
# Enter the temperature10
# Enter the humidity23
# Pests per plant:0,Damage:25%,temp:10C,humidity:23%
# Severity level:High
#  Recommendation: Immediate action required
#  cost of intervention=1000/ha

# %%
crop=input("Enter crop name")
days=int(input("Enter the no. of days"))
print(f"crop: {crop},days since sowing: {days}")
if crop == "rice":
  if days<120:
    print("Status:Not reday to harvest \n maturity range=120-150\n Recommendatioin :wait till maturity period")
  elif(120<days<150):
    print("Status: Ready to harvest\n maturity range=120-150\n Recommendatioin :Begin harvest")
  else:
    print("maturity period over")
if crop == "Wheat":
  if days<140:
    print("Status:Not reday to harvest \n maturity range=140-180\n Recommendatioin :wait till maturity period")
  elif (140<days<180):
    print("Status: Ready to harvest\n maturity range=140-180\n Recommendatioin :Begin harvest")
  else:
    print("maturity period over")
if crop == "cotton":
    if days<160:
      print("Status:Not reday to harvest \n maturity range=160-200\n Recommendatioin :wait till maturity period")
    elif(160<days<200):
      print("Status: Ready to harvest\n maturity range=160-200\n Recommendatioin :Begin harvest")
    else:
      print("maturity period over")
# Out:
# Enter crop namecotton
# Enter the no. of days300
# crop: cotton,days since sowing: 300
# maturity period over

# %%
rainfall=int(input("Enter the rainfall"))
temp=int(input("Enter the temperature"))
windspeed=int(input("Enter the windspeed"))
print(f"Rainfall: {rainfall},Temperature: {temp}C,Windspeed: {windspeed}km/hr")
if rainfall>50:
  print("Delay planting, do field preparation")
elif temp>38:
  print("Delay activities,focus on irrigation")
elif windspeed>40:
  print("cancel spray operation")
else:
  print("Go ahead with Planned activities")
# Out:
# Enter the rainfall51
# Enter the temperature37
# Enter the windspeed41
# Rainfall: 51,Temperature: 37C,Windspeed: 41km/hr
# Delay planting, do field preparation

# %%
rainfall=int(input("Enter the rainfall"))
temp=int(input("Enter the temperature"))
windspeed=int(input("Enter the windspeed"))
print(f"Rainfall: {rainfall},Temperature: {temp}C,Windspeed: {windspeed}km/hr")
if rainfall>50 and temp>38 and windspeed>40:
  print("Delay planting, do field preparation \n Delay activities,focus on irrigation \n cancel spray operation ")
else:
  print("Go ahead with Planned activities")
# Out:
# Enter the rainfall51
# Enter the temperature37
# Enter the windspeed41
# Rainfall: 51,Temperature: 37C,Windspeed: 41km/hr
# Go ahead with Planned activities

# %%
rainfall=int(input("Enter the rainfall"))
temp=int(input("Enter the temperature"))
soilquality=int(input("Enter the soil quality"))
yeild=40
print(f"Rainfall: {rainfall},Temperature: {temp}C,soilquality: {soilquality}")
if rainfall>600:
  (rainfall-600)
  yeild=yeild+(yeild*((rainfall-600)/500))
  print("Yeild:",yeild)
elif rainfall<400:
  (400-rainfall)
  yeild=yeild-(yeild*((400-rainfall)/500))
  printprint("Yeild:",yeild)
if temp>30:
  (temp-30)
  yeild=yeild+(yeild*((temp-30)/100))
  print("Yeild:",yeild)
elif temp<25:
  (25-temp)
  yeild=yeild-(yeild*((25-temp)/100))
  print("Yeild:",yeild)
# Out:
# Enter the rainfall610
# Enter the temperature31
# Enter the soil quality60
# Rainfall: 610,Temperature: 31C,soilquality: 60
# Yeild: 40.8
# Yeild: 41.208
