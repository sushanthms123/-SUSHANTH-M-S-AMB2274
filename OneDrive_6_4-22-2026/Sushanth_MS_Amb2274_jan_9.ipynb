# %%
with open("attendence.txt","w")as f:
 f.write("date=7/1/26 \n Sushanth-p \n Rakesh-p \n Ranga-p \n Nandeesh-p")
with open("attendence.txt","a")as f:
 f.write("\n Thanishk-A")
with open("attendence.txt","r")as f:
 print(f.read())
# Out:
# date=7/1/26
#  Sushanth-p
#  Rakesh-p
#  Ranga-p
#  Nandeesh-p
#  Thanishk-A

# %%
with open("Daily expenses.txt","w")as f:
 f.write("date=7/1/26 \n amount=800 \n purpose=eating \n Category=food")
with open("Daily expenses.txt","a")as f:
 f.write("\n \ndate=8/1/26\namount=900 \n purpose=movie \n Category=entertainment")
with open("Daily expenses.txt","r")as f:
 print(f.read())
# Out:
# date=7/1/26
#  amount=800
#  purpose=eating
#  Category=food
#
# date=8/1/26
# amount=900
#  purpose=movie
#  Category=entertainment

# %%
entry=input("Write ur journal entry:\n ")
with open("journal.txt","w")as f:
  with open("journal.txt","a")as f:
    f.write(entry)
with open("journal.txt","r")as f:
 print(f.read())
# Out:
# Write ur journal entry:
#  hi
# hi

# %%
import numpy as np
a=np.array([1,2])
b=np.array([3,4])
print(a+b)
# Out:
# [4 6]

# %%
import numpy as np
x=np.array([
    [1,2],
    [3,4],
    [5,6]
])
print(x)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
np.dot([1,2],[3,4])
# Out:
# np.int64(11)

# %%
import numpy as np
scores=[50,60,70]
print(np.mean(scores))
# Out:
# 60.0

# %%
w=6
lr=0.1
for i in range(6):
  w=w-lr*2*w
  print(w)
# Out:
# 4.8
# 3.84
# 3.072
# 2.4576000000000002
# 1.9660800000000003
# 1.5728640000000003

# %%
import random
outcome=["spam","not spam"]
print(random.choice(outcome))
# Out:
# not spam
