# %%
 import numpy as np
 arr = np.array([[1,2,3],[4,5,6]])
 print(arr.ndim)
# Out:
# 2

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
print(arr.shape)
# Out:
# (2, 3)

# %%
 import numpy as np
 arr = np.array([1,2,3])
 print(arr.itemsize)
# Out:
# 8
