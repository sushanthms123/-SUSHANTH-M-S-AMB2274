# %%
scores=(input("Enter the score"))
import numpy as np
scores=np.array(scores.split(","),dtype=int)
print(np.mean(scores))
# Out:
# Enter the score34,4,45
# 27.666666666666668

# %%
import numpy as np
cricket_scores=[60,40,70,100]
print(np.mean(cricket_scores))
# Out:
# 67.5

# %%
import numpy as np
cricket_scores=[60,40,70,100]
median_score=np.median(cricket_scores)
print(f"Median:{median_score}")
# Out:
# Median:65.0

# %%
votes=(input("Enter the no. of votes:"))
from statistics import mode
most_common=(mode(votes))
print("most common votes:",most_common)
# Out:
# Enter the no. of votes:1234567777
# most common votes: 7

# %%
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,120]
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 40.824829046386306

# %%
import random
#stimulating random predictions
for i in range(5):
  prediction=random.choice(["spam","not spam"])
  print(f"Emial{i+1}:{prediction}")
# Out:
# Emial1:not spam
# Emial2:not spam
# Emial3:spam
# Emial4:not spam
# Emial5:spam

# %%
import random
#stimulate 10 dice roll
samples=[random.randint(1,6)
for i in range(10)]
print("sample rolls",samples)
print("sample means:",sum(samples)/len(samples))
# Out:
# sample rolls [2, 1, 6, 5, 2, 5, 6, 4, 6, 3]
# sample means: 4.0
